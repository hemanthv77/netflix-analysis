# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set up plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 2. Load Your Dataset
# Replace 'your_dataset.csv' with your actual filename

# %%
# Define the path to your dataset
dataset_path = Path('../Datasets/your_dataset.csv')

# Load the dataset
# For CSV files:
df = pd.read_csv(dataset_path)

# For Excel files, uncomment:
# df = pd.read_excel(dataset_path)

# For JSON files, uncomment:
# df = pd.read_json(dataset_path)

print(f"Dataset loaded successfully!")
print(f"Shape: {df.shape}")

# %% [markdown]
# ## 3. Explore Your Data

# %%
# Display first few rows
df.head()

# %%
# Display dataset information
df.info()

# %%
# Display statistical summary
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %% [markdown]
# ## 4. Data Visualization

# %%
# Example: Plot distribution of a column
# Replace 'column_name' with your actual column
# df['column_name'].hist(bins=30, edgecolor='black')
# plt.title('Distribution')
# plt.xlabel('Values')
# plt.ylabel('Frequency')
# plt.show()

# %% [markdown]
# ## 5. Data Analysis & Insights
# Add your analysis code here

# %%
# Your analysis code here
pass
